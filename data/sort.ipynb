# %%
import pandas as pd
import operator

# %%
a1 = pd.read_excel('mydata.xlsx', header=0)
df = pd.DataFrame(a1)

# %%
alist = a1.values.tolist()

# %%
alist[1][1]
# Out:
# 0.956

# %%
a = []
b = []
dic1 = []

# %%
for x in range(11):
    a = alist[x][0]
    b = alist[x][1]
    c = alist[x][2]
    d = alist[x][3]
    e = alist[x][4]
    f = alist[x][5]
    g = alist[x][6]
    h = alist[x][7]
    i = alist[x][8]
    j = alist[x][9]
    k = alist[x][10]
    l = alist[x][11]
    m = alist[x][12]
    n = alist[x][13]
    o = alist[x][14]
    p = alist[x][15]
    q = alist[x][16]
    dic1 = {'서울특별시':a, '부산광역시':b, '대구광역시':c, '인천광역시':d, '광주광역시':e,'대전광역시':f,'울산광역시':g, '세종특별자치시':h, '경기도':i, '강원도':j,'충청북도':k,'충청남도':l,'전라북도':m,'전라남도':n,'경상북도':o,'경상남도':p,'제주특별자치도':q
    }
    dic = {}

    #for k, v in dic1.items():
        #dic[v] = k

    s_dic= sorted(dic1.items(), key=operator.itemgetter(1), reverse = True)
    a = list(s_dic)
    print(s_dic, '\n')
    for i in range(17):
        print('"'+s_dic[i][0]+'",', end=' ')
    print('\n')
    for i in range(17):
        print(s_dic[i][1],',', end=' ')
    print('\n')
# Out:
# [('제주특별자치도', 38.6), ('전라남도', 36.2), ('충청남도', 36.1), ('경상북도', 36.0), ('인천광역시', 35.1), ('강원도', 35.0), ('충청북도', 34.7), ('경상남도', 34.2), ('경기도', 33.6), ('광주광역시', 33.3), ('울산광역시', 33.1), ('전라북도', 33.0), ('대구광역시', 32.5), ('부산광역시', 32.3), ('서울특별시', 31.3), ('세종특별자치시', 31.0), ('대전광역시', 30.0)]
#
# "제주특별자치도", "전라남도", "충청남도", "경상북도", "인천광역시", "강원도", "충청북도", "경상남도", "경기도", "광주광역시", "울산광역시", "전라북도", "대구광역시", "부산광역시", "서울특별시", "세종특별자치시", "대전광역시",
#
# 38.6 , 36.2 , 36.1 , 36.0 , 35.1 , 35.0 , 34.7 , 34.2 , 33.6 , 33.3 , 33.1 , 33.0 , 32.5 , 32.3 , 31.3 , 31.0 , 30.0 ,
#
# [('대전광역시', 0.967), ('세종특별자치시', 0.965), ('전라남도', 0.963), ('대구광역시', 0.959), ('울산광역시', 0.959), ('광주광역시', 0.958), ('경상북도', 0.958), ('경상남도', 0.958), ('부산광역시', 0.956), ('경기도', 0.956), ('제주특별자치도', 0.956), ('서울특별시', 0.953), ('인천광역시', 0.953), ('강원도', 0.953), ('충청북도', 0.953), ('전라북도', 0.953), ('충청남도', 0.947)]
#
# ...

# %%
a
# Out:
# [(36.8, '전라남도'),
#  (33.1, '경상남도'),
#  (33.0, '전라북도'),
#  (32.8, '강원도'),
#  (29.9, '충청남도'),
#  (28.0, '경상북도'),
#  (27.5, '제주특별자치도'),
#  (27.4, '충청북도'),
#  (24.8, '세종특별자치시'),
#  (24.4, '울산광역시'),
#  (21.8, '광주광역시'),
#  (21.5, '부산광역시'),
#  (20.7, '인천광역시'),
#  (19.8, '서울특별시'),
#  (19.7, '경기도'),
#  (18.4, '대전광역시'),
#  (18.2, '대구광역시'),
#  (36.8, '전라남도'),
#  (33.1, '경상남도'),
#  (33.0, '전라북도'),
#  (32.8, '강원도'),
#  (29.9, '충청남도'),
#  (28.0, '경상북도'),
#  (27.5, '제주특별자치도'),
#  (27.4, '충청북도'),
#  (24.8, '세종특별자치시'),
#  (24.4, '울산광역시'),
#  (21.8, '광주광역시'),
#  (21.5, '부산광역시'),
#  (20.7, '인천광역시'),
#  (19.8, '서울특별시'),
#  (19.7, '경기도'),
#  (18.4, '대전광역시'),
#  (18.2, '대구광역시')]
